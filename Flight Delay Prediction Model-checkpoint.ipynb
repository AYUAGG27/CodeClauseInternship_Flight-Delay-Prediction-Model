# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flights=pd.read_csv('flights.csv')
flights=flights.sample(n=100000)
flights.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6464\664831390.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   flights=pd.read_csv('flights.csv')
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 4982823  2015     11    8            7      WN           4065      N603SW
# 5044322  2015     11   11            3      OO           5196      N719SK
# 2187034  2015      5   19            2      WN           2450      N387SW
# 3070187  2015      7   12            7      DL           2647      N927AT
# 1212329  2015      3   20            5      UA           1555      N73283
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 4982823            RIC                 ATL                  600  ...
# 5044322            MLI                 ORD                 1904  ...
# 2187034            CMH                 BWI                 1340  ...
# 3070187            LFT                 ATL                  600  ...
# 1212329            SAT                 DEN                  910  ...
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 4982823         737.0          -13.0         0          0
# 5044322           NaN            NaN         0          1
# 2187034        1447.0           -8.0         0          0
# 3070187         842.0            1.0         0          0
# 1212329        1011.0          -22.0         0          0
#
#          CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 4982823                  NaN               NaN             NaN            NaN
# 5044322                    C               NaN             NaN            NaN
# 2187034                  NaN               NaN             NaN            NaN
# 3070187                  NaN               NaN             NaN            NaN
# 1212329                  NaN               NaN             NaN            NaN
#
#          LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 4982823                  NaN            NaN
# 5044322                  NaN            NaN
# 2187034                  NaN            NaN
# 3070187                  NaN            NaN
# 1212329                  NaN            NaN
#
# [5 rows x 31 columns]

# %%
flights.shape
# Out:
# (100000, 31)

# %%
flights.isnull().values.any()
# Out:
# True

# %%
flights.isnull().sum()
# Out:
# YEAR                       0
# MONTH                      0
# DAY                        0
# DAY_OF_WEEK                0
# AIRLINE                    0
# FLIGHT_NUMBER              0
# TAIL_NUMBER              254
# ORIGIN_AIRPORT             0
# DESTINATION_AIRPORT        0
# SCHEDULED_DEPARTURE        0
# DEPARTURE_TIME          1470
# DEPARTURE_DELAY         1470
# TAXI_OUT                1518
# WHEELS_OFF              1518
# SCHEDULED_TIME             0
# ELAPSED_TIME            1806
# AIR_TIME                1806
# DISTANCE                   0
# WHEELS_ON               1589
# TAXI_IN                 1589
# SCHEDULED_ARRIVAL          0
# ARRIVAL_TIME            1589
# ARRIVAL_DELAY           1806
# DIVERTED                   0
# CANCELLED                  0
# CANCELLATION_REASON    98466
# AIR_SYSTEM_DELAY       81479
# SECURITY_DELAY         81479
# AIRLINE_DELAY          81479
# LATE_AIRCRAFT_DELAY    81479
# WEATHER_DELAY          81479
# dtype: int64

# %%
sns.countplot(x='CANCELLATION_REASON',data=flights)
# Out:
# <Axes: xlabel='CANCELLATION_REASON', ylabel='count'>

# %%
sns.countplot(x="MONTH",hue="CANCELLATION_REASON",data=flights)
# Out:
# <Axes: xlabel='MONTH', ylabel='count'>

# %%
plt.figure(figsize=(10, 10))
axis = sns.countplot(x=flights['ORIGIN_AIRPORT'], data =flights, order=flights['ORIGIN_AIRPORT'].value_counts().iloc[:20].index)
axis.set_xticklabels(axis.get_xticklabels(), rotation=90, ha="right")
plt.tight_layout()
plt.show()

# %%
axis = plt.subplots(figsize=(10,14))
Name = flights["AIRLINE"].unique()
size = flights["AIRLINE"].value_counts()
plt.pie(size,labels=Name,autopct='%5.0f%%')
plt.show()

# %%
variables_to_remove=["YEAR","FLIGHT_NUMBER","TAIL_NUMBER","DEPARTURE_TIME","TAXI_OUT","WHEELS_OFF","ELAPSED_TIME","AIR_TIME","WHEELS_ON","TAXI_IN","ARRIVAL_TIME","DIVERTED","CANCELLED","CANCELLATION_REASON","AIR_SYSTEM_DELAY", "SECURITY_DELAY","AIRLINE_DELAY","LATE_AIRCRAFT_DELAY","WEATHER_DELAY","SCHEDULED_TIME","SCHEDULED_ARRIVAL"]
flights.drop(variables_to_remove,axis=1,inplace= True)
flights.columns
# Out:
# Index(['MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'ORIGIN_AIRPORT',
#        'DESTINATION_AIRPORT', 'SCHEDULED_DEPARTURE', 'DEPARTURE_DELAY',
#        'DISTANCE', 'ARRIVAL_DELAY'],
#       dtype='object')

# %%
airport = pd.read_csv('airports.csv')
airport
# Out:
#     IATA_CODE                              AIRPORT  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 0                         Allentown    PA     USA  40.65236  -75.44040
# 1                           Abilene    TX     USA  32.41132  -99.68190
# 2                       Albuquerque    NM     USA  35.04022 -106.60919
# 3                          Aberdeen    SD     USA  45.44906  -98.42183
# 4                            Albany    GA     USA  31.53552  -84.19447
# ..                              ...   ...     ...       ...        ...
# 317                        Wrangell    AK     USA  56.48433 -132.36982
# 318                West Yellowstone    MT     USA  44.68840 -111.11764
# 319  Fayetteville/Springdale/Rogers    AR     USA  36.28187  -94.30681
# 320                         Yakutat    AK     USA  59.50336 -139.66023
# 321                            Yuma    AZ     USA  32.65658 -114.60597
#
# [322 rows x 7 columns]

# %%
flights.loc[~flights.ORIGIN_AIRPORT.isin(airport.IATA_CODE.values),'ORIGIN_AIRPORT']='OTHER'
flights.loc[~flights.DESTINATION_AIRPORT.isin(airport.IATA_CODE.values),'DESTINATION_AIRPORT']='OTHER'
flights
# Out:
#          MONTH  DAY  DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 4982823     11    8            7      WN            RIC                 ATL
# 5044322     11   11            3      OO            MLI                 ORD
# 2187034      5   19            2      WN            CMH                 BWI
# 3070187      7   12            7      DL            LFT                 ATL
# 1212329      3   20            5      UA            SAT                 DEN
# ...        ...  ...          ...     ...            ...                 ...
# 3233553      7   21            2      DL            MCO                 DTW
# 3999372      9    6            7      OO            IDA                 DEN
# 923187       3    2            1      UA            LGA                 ORD
# 1095912      3   13            5      UA            EWR                 PBI
# 1545483      4    9            4      DL            LIT                 ATL
#
#          SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  ARRIVAL_DELAY
# 4982823                  600             -4.0       481          -13.0
# 5044322                 1904              NaN       139            NaN
# 2187034                 1340             -5.0       337           -8.0
# 3070187                  600              0.0       503            1.0
# 1212329                  910            -11.0       794          -22.0
# ...                      ...              ...       ...            ...
# 3233553                 1600             53.0       957           42.0
# 3999372                  600             41.0       458           22.0
# 923187                  1400             15.0       733           17.0
# 1095912                  725              6.0      1023          -14.0
# 1545483                 1716             -1.0       453          -11.0
#
# [100000 rows x 10 columns]

# %%
print(flights.ORIGIN_AIRPORT.nunique())
print(flights.DESTINATION_AIRPORT.nunique())
print(flights.AIRLINE.nunique())
  

flights=flights.dropna()
flights
# Out:
# 319
# 319
# 14
#          MONTH  DAY  DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 4982823     11    8            7      WN            RIC                 ATL
# 2187034      5   19            2      WN            CMH                 BWI
# 3070187      7   12            7      DL            LFT                 ATL
# 1212329      3   20            5      UA            SAT                 DEN
# 4317123      9   26            6      UA            DEN                 PDX
# ...        ...  ...          ...     ...            ...                 ...
# 3233553      7   21            2      DL            MCO                 DTW
# 3999372      9    6            7      OO            IDA                 DEN
# 923187       3    2            1      UA            LGA                 ORD
# 1095912      3   13            5      UA            EWR                 PBI
# 1545483      4    9            4      DL            LIT                 ATL
#
#          SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  ARRIVAL_DELAY
# 4982823                  600             -4.0       481          -13.0
# 2187034                 1340             -5.0       337           -8.0
# 3070187                  600              0.0       503            1.0
# 1212329                  910            -11.0       794          -22.0
# 4317123                 1515              0.0       991          -16.0
# ...                      ...              ...       ...            ...
# 3233553                 1600             53.0       957           42.0
# 3999372                  600             41.0       458           22.0
# 923187                  1400             15.0       733           17.0
# 1095912                  725              6.0      1023          -14.0
# 1545483                 1716             -1.0       453          -11.0
#
# [98194 rows x 10 columns]

# %%
flights.shape
# Out:
# (98194, 10)

# %%
df=pd.DataFrame(flights)
df['DAY_OF_WEEK']= df['DAY_OF_WEEK'].apply(str)
df["DAY_OF_WEEK"].replace({"1":"SUNDAY", "2": "MONDAY", "3": "TUESDAY", "4":"WEDNESDAY", "5":"THURSDAY", "6":"FRIDAY", "7":"SATURDAY"},inplace=True)
flights
# Out:
#          MONTH  DAY  DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 4982823     11    8            7      WN            RIC                 ATL
# 2187034      5   19            2      WN            CMH                 BWI
# 3070187      7   12            7      DL            LFT                 ATL
# 1212329      3   20            5      UA            SAT                 DEN
# 4317123      9   26            6      UA            DEN                 PDX
# ...        ...  ...          ...     ...            ...                 ...
# 3233553      7   21            2      DL            MCO                 DTW
# 3999372      9    6            7      OO            IDA                 DEN
# 923187       3    2            1      UA            LGA                 ORD
# 1095912      3   13            5      UA            EWR                 PBI
# 1545483      4    9            4      DL            LIT                 ATL
#
#          SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  ARRIVAL_DELAY
# 4982823                  600             -4.0       481          -13.0
# 2187034                 1340             -5.0       337           -8.0
# 3070187                  600              0.0       503            1.0
# 1212329                  910            -11.0       794          -22.0
# 4317123                 1515              0.0       991          -16.0
# ...                      ...              ...       ...            ...
# 3233553                 1600             53.0       957           42.0
# 3999372                  600             41.0       458           22.0
# 923187                  1400             15.0       733           17.0
# 1095912                  725              6.0      1023          -14.0
# 1545483                 1716             -1.0       453          -11.0
#
# [98194 rows x 10 columns]

# %%
dums = ['AIRLINE','ORIGIN_AIRPORT','DESTINATION_AIRPORT','DAY_OF_WEEK']
df_cat=pd.get_dummies(df[dums],drop_first=True)
df_cat
# Out:
#          AIRLINE_AS  AIRLINE_B6  AIRLINE_DL  AIRLINE_EV  AIRLINE_F9  \
# 4982823       False       False       False       False       False
# 2187034       False       False       False       False       False
# 3070187       False       False        True       False       False
# 1212329       False       False       False       False       False
# 4317123       False       False       False       False       False
# ...             ...         ...         ...         ...         ...
# 3233553       False       False        True       False       False
# 3999372       False       False       False       False       False
# 923187        False       False       False       False       False
# 1095912       False       False       False       False       False
# 1545483       False       False        True       False       False
#
#          AIRLINE_HA  AIRLINE_MQ  AIRLINE_NK  AIRLINE_OO  AIRLINE_UA  ...  \
# 4982823       False       False       False       False       False  ...
# 2187034       False       False       False       False       False  ...
# 3070187       False       False       False       False       False  ...
# 1212329       False       False       False       False        True  ...
# 4317123       False       False       False       False        True  ...
# ...             ...         ...         ...         ...         ...  ...
# 3233553       False       False       False       False       False  ...
# 3999372       False       False       False        True       False  ...
# 923187        False       False       False       False        True  ...
# 1095912       False       False       False       False        True  ...
# 1545483       False       False       False       False       False  ...
#
#          DESTINATION_AIRPORT_WYS  DESTINATION_AIRPORT_XNA  \
# 4982823                    False                    False
# 2187034                    False                    False
# 3070187                    False                    False
# 1212329                    False                    False
# 4317123                    False                    False
# ...                          ...                      ...
# 3233553                    False                    False
# 3999372                    False                    False
# 923187                     False                    False
# 1095912                    False                    False
# 1545483                    False                    False
#
#          DESTINATION_AIRPORT_YAK  DESTINATION_AIRPORT_YUM  DAY_OF_WEEK_MONDAY  \
# 4982823                    False                    False               False
# 2187034                    False                    False                True
# 3070187                    False                    False               False
# 1212329                    False                    False               False
# 4317123                    False                    False               False
# ...                          ...                      ...                 ...
# 3233553                    False                    False                True
# 3999372                    False                    False               False
# 923187                     False                    False               False
# 1095912                    False                    False               False
# 1545483                    False                    False               False
#
#          DAY_OF_WEEK_SATURDAY  DAY_OF_WEEK_SUNDAY  DAY_OF_WEEK_THURSDAY  \
# 4982823                  True               False                 False
# 2187034                 False               False                 False
# 3070187                  True               False                 False
# 1212329                 False               False                  True
# 4317123                 False               False                 False
# ...                       ...                 ...                   ...
# 3233553                 False               False                 False
# 3999372                  True               False                 False
# 923187                  False                True                 False
# 1095912                 False               False                  True
# 1545483                 False               False                 False
#
#          DAY_OF_WEEK_TUESDAY  DAY_OF_WEEK_WEDNESDAY
# 4982823                False                  False
# 2187034                False                  False
# 3070187                False                  False
# 1212329                False                  False
# 4317123                False                  False
# ...                      ...                    ...
# 3233553                False                  False
# 3999372                False                  False
# 923187                 False                  False
# 1095912                False                  False
# 1545483                False                   True
#
# [98194 rows x 655 columns]

# %%
df_cat.columns
# Out:
# Index(['AIRLINE_AS', 'AIRLINE_B6', 'AIRLINE_DL', 'AIRLINE_EV', 'AIRLINE_F9',
#        'AIRLINE_HA', 'AIRLINE_MQ', 'AIRLINE_NK', 'AIRLINE_OO', 'AIRLINE_UA',
#        ...
#        'DESTINATION_AIRPORT_WYS', 'DESTINATION_AIRPORT_XNA',
#        'DESTINATION_AIRPORT_YAK', 'DESTINATION_AIRPORT_YUM',
#        'DAY_OF_WEEK_MONDAY', 'DAY_OF_WEEK_SATURDAY', 'DAY_OF_WEEK_SUNDAY',
#        'DAY_OF_WEEK_THURSDAY', 'DAY_OF_WEEK_TUESDAY', 'DAY_OF_WEEK_WEDNESDAY'],
#       dtype='object', length=655)

# %%
var_to_remove=["DAY_OF_WEEK","AIRLINE","ORIGIN_AIRPORT","DESTINATION_AIRPORT"]
df.drop(var_to_remove,axis=1,inplace=True)
df
# Out:
#          MONTH  DAY  SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  \
# 4982823     11    8                  600             -4.0       481
# 2187034      5   19                 1340             -5.0       337
# 3070187      7   12                  600              0.0       503
# 1212329      3   20                  910            -11.0       794
# 4317123      9   26                 1515              0.0       991
# ...        ...  ...                  ...              ...       ...
# 3233553      7   21                 1600             53.0       957
# 3999372      9    6                  600             41.0       458
# 923187       3    2                 1400             15.0       733
# 1095912      3   13                  725              6.0      1023
# 1545483      4    9                 1716             -1.0       453
#
#          ARRIVAL_DELAY
# 4982823          -13.0
# 2187034           -8.0
# 3070187            1.0
# 1212329          -22.0
# 4317123          -16.0
# ...                ...
# 3233553           42.0
# 3999372           22.0
# 923187            17.0
# 1095912          -14.0
# 1545483          -11.0
#
# [98194 rows x 6 columns]

# %%
data=pd.concat([df,df_cat],axis=1)
data
# Out:
#          MONTH  DAY  SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  \
# 4982823     11    8                  600             -4.0       481
# 2187034      5   19                 1340             -5.0       337
# 3070187      7   12                  600              0.0       503
# 1212329      3   20                  910            -11.0       794
# 4317123      9   26                 1515              0.0       991
# ...        ...  ...                  ...              ...       ...
# 3233553      7   21                 1600             53.0       957
# 3999372      9    6                  600             41.0       458
# 923187       3    2                 1400             15.0       733
# 1095912      3   13                  725              6.0      1023
# 1545483      4    9                 1716             -1.0       453
#
#          ARRIVAL_DELAY  AIRLINE_AS  AIRLINE_B6  AIRLINE_DL  AIRLINE_EV  ...  \
# 4982823          -13.0       False       False       False       False  ...
# 2187034           -8.0       False       False       False       False  ...
# 3070187            1.0       False       False        True       False  ...
# 1212329          -22.0       False       False       False       False  ...
# 4317123          -16.0       False       False       False       False  ...
# ...                ...         ...         ...         ...         ...  ...
# 3233553           42.0       False       False        True       False  ...
# 3999372           22.0       False       False       False       False  ...
# 923187            17.0       False       False       False       False  ...
# 1095912          -14.0       False       False       False       False  ...
# 1545483          -11.0       False       False        True       False  ...
#
#          DESTINATION_AIRPORT_WYS  DESTINATION_AIRPORT_XNA  \
# 4982823                    False                    False
# 2187034                    False                    False
# 3070187                    False                    False
# 1212329                    False                    False
# 4317123                    False                    False
# ...                          ...                      ...
# 3233553                    False                    False
# 3999372                    False                    False
# 923187                     False                    False
# 1095912                    False                    False
# 1545483                    False                    False
#
#          DESTINATION_AIRPORT_YAK  DESTINATION_AIRPORT_YUM  DAY_OF_WEEK_MONDAY  \
# 4982823                    False                    False               False
# 2187034                    False                    False                True
# 3070187                    False                    False               False
# 1212329                    False                    False               False
# 4317123                    False                    False               False
# ...                          ...                      ...                 ...
# 3233553                    False                    False                True
# 3999372                    False                    False               False
# 923187                     False                    False               False
# 1095912                    False                    False               False
# 1545483                    False                    False               False
#
#          DAY_OF_WEEK_SATURDAY  DAY_OF_WEEK_SUNDAY  DAY_OF_WEEK_THURSDAY  \
# 4982823                  True               False                 False
# 2187034                 False               False                 False
# 3070187                  True               False                 False
# 1212329                 False               False                  True
# 4317123                 False               False                 False
# ...                       ...                 ...                   ...
# 3233553                 False               False                 False
# 3999372                  True               False                 False
# 923187                  False                True                 False
# 1095912                 False               False                  True
# 1545483                 False               False                 False
#
#          DAY_OF_WEEK_TUESDAY  DAY_OF_WEEK_WEDNESDAY
# 4982823                False                  False
# 2187034                False                  False
# 3070187                False                  False
# 1212329                False                  False
# 4317123                False                  False
# ...                      ...                    ...
# 3233553                False                  False
# 3999372                False                  False
# 923187                 False                  False
# 1095912                False                  False
# 1545483                False                   True
#
# [98194 rows x 661 columns]

# %%
final_data = data.sample(n=60000)
final_data
# Out:
#          MONTH  DAY  SCHEDULED_DEPARTURE  DEPARTURE_DELAY  DISTANCE  \
# 2881263      6   30                 1329              9.0      1089
# 2591315      6   13                  845             -3.0      2520
# 4546111     10   11                  921             -2.0      1012
# 5376426     12    3                 1009             -3.0      1009
# 2460420      6    5                 1155             -4.0       158
# ...        ...  ...                  ...              ...       ...
# 1961148      5    5                 1440              9.0      2454
# 3944659      9    2                 1245             27.0       412
# 688409       2   15                 1357             -7.0      1846
# 1478987      4    5                 1730             -4.0       265
# 2700244      6   19                 1620              3.0       425
#
#          ARRIVAL_DELAY  AIRLINE_AS  AIRLINE_B6  AIRLINE_DL  AIRLINE_EV  ...  \
# 2881263           40.0       False       False        True       False  ...
# 2591315           -5.0        True       False       False       False  ...
# 4546111          -21.0       False       False       False       False  ...
# 5376426           -6.0       False       False       False       False  ...
# 2460420           -7.0       False       False       False       False  ...
# ...                ...         ...         ...         ...         ...  ...
# 1961148           -5.0       False       False       False       False  ...
# 3944659           31.0       False       False       False       False  ...
# 688409             6.0       False       False       False       False  ...
# 1478987           -7.0       False       False       False        True  ...
# 2700244           14.0       False       False       False       False  ...
#
#          DESTINATION_AIRPORT_WYS  DESTINATION_AIRPORT_XNA  \
# 2881263                    False                    False
# 2591315                    False                    False
# 4546111                    False                    False
# 5376426                    False                    False
# 2460420                    False                    False
# ...                          ...                      ...
# 1961148                    False                    False
# 3944659                    False                    False
# 688409                     False                    False
# 1478987                    False                    False
# 2700244                    False                    False
#
#          DESTINATION_AIRPORT_YAK  DESTINATION_AIRPORT_YUM  DAY_OF_WEEK_MONDAY  \
# 2881263                    False                    False                True
# 2591315                    False                    False               False
# 4546111                    False                    False               False
# 5376426                    False                    False               False
# 2460420                    False                    False               False
# ...                          ...                      ...                 ...
# 1961148                    False                    False                True
# 3944659                    False                    False               False
# 688409                     False                    False               False
# 1478987                    False                    False               False
# 2700244                    False                    False               False
#
#          DAY_OF_WEEK_SATURDAY  DAY_OF_WEEK_SUNDAY  DAY_OF_WEEK_THURSDAY  \
# 2881263                 False               False                 False
# 2591315                 False               False                 False
# 4546111                  True               False                 False
# 5376426                 False               False                 False
# 2460420                 False               False                  True
# ...                       ...                 ...                   ...
# 1961148                 False               False                 False
# 3944659                 False               False                 False
# 688409                   True               False                 False
# 1478987                  True               False                 False
# 2700244                 False               False                  True
#
#          DAY_OF_WEEK_TUESDAY  DAY_OF_WEEK_WEDNESDAY
# 2881263                False                  False
# 2591315                False                  False
# 4546111                False                  False
# 5376426                False                   True
# 2460420                False                  False
# ...                      ...                    ...
# 1961148                False                  False
# 3944659                 True                  False
# 688409                 False                  False
# 1478987                False                  False
# 2700244                False                  False
#
# [60000 rows x 661 columns]

# %%
x=flights.drop(columns=['MONTH','DAY','DAY_OF_WEEK','AIRLINE','ORIGIN_AIRPORT','DESTINATION_AIRPORT','SCHEDULED_DEPARTURE','ARRIVAL_DELAY'])
y=flights['MONTH']
print(x)
print(y)
# Out:
#          DEPARTURE_DELAY  DISTANCE
# 4982823             -4.0       481
# 2187034             -5.0       337
# 3070187              0.0       503
# 1212329            -11.0       794
# 4317123              0.0       991
# ...                  ...       ...
# 3233553             53.0       957
# 3999372             41.0       458
# 923187              15.0       733
# 1095912              6.0      1023
# 1545483             -1.0       453
#
# [98194 rows x 2 columns]
# 4982823    11
# 2187034     5
# 3070187     7
# 1212329     3
# 4317123     9
#            ..
# 3233553     7
# 3999372     9
# 923187      3
# 1095912     3
# 1545483     4
# Name: MONTH, Length: 98194, dtype: int64

# %%
df.dropna(inplace=True)

# %%
sns.heatmap(data.isnull(), cbar = False)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.6, random_state = 42)
print(x.shape, X_train.shape, X_test.shape)
# Out:
# (98194, 2) (39277, 2) (58917, 2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
Scaler = StandardScaler()

# %%
from sklearn.linear_model import LogisticRegression

# Assuming 'x' and 'y' are your features and target variable
model = LogisticRegression()
model.fit(x, y)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score

# %%
confusion_matrix (y_test, y_pred)
# Out:
# array([[   0,    0,    0,    0,    0,  358, 2927,    0,    1, 1457,    0,
#            0],
#        [   0,    0,    0,    0,    0,  397, 2643,    0,    0, 1180,    0,
#            0],
#        [   0,    0,    0,    0,    0,  374, 3174,    0,    0, 1469,    0,
#            0],
#        [   0,    0,    0,    0,    0,  331, 2974,    0,    1, 1603,    0,
#            0],
#        [   0,    0,    0,    0,    0,  380, 3106,    0,    3, 1595,    0,
#            0],
#        [   0,    0,    0,    0,    0,  452, 3231,    0,    0, 1288,    0,
#            0],
#        [   0,    0,    0,    0,    0,  459, 3487,    0,    2, 1483,    0,
#            0],
#        [   0,    0,    0,    0,    0,  374, 3220,    0,    1, 1536,    0,
#            0],
#        [   0,    0,    0,    0,    0,  222, 2786,    0,    0, 1715,    0,
#            0],
#        [   0,    0,    0,    0,    0,  235, 3082,    0,    1, 1752,    0,
#            0],
#        [   0,    0,    0,    0,    0,  266, 3036,    0,    0, 1545,    0,
#            0],
#        [   0,    0,    0,    0,    0,  391, 3075,    0,    0, 1305,    0,
#            0]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00      4743
#            2       0.00      0.00      0.00      4220
#            3       0.00      0.00      0.00      5017
#            4       0.00      0.00      0.00      4909
#            5       0.00      0.00      0.00      5084
#            6       0.11      0.09      0.10      4971
#            7       0.09      0.64      0.17      5431
#            8       0.00      0.00      0.00      5131
#            9       0.00      0.00      0.00      4723
#           10       0.10      0.35      0.15      5070
#           11       0.00      0.00      0.00      4847
#           12       0.00      0.00      0.00      4771
#
#     accuracy                           0.10     58917
#    macro avg       0.02      0.09      0.03     58917
# weighted avg       0.03      0.10      0.04     58917
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.0965935129079892
